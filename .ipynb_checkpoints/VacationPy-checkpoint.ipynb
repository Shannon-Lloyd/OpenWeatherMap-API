# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import json

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat      Lng  Max Temp  Humidity  \
# 0        0          grytviken -54.2811 -36.5092     -5.36        76
# 1        1           coruripe -10.1256 -36.1756     22.46        79
# 2        2               lebu -37.6167 -73.6500      7.65        88
# 3        3        saint peter  13.2500 -59.6167     26.31        77
# 4        4  port-aux-francais -49.3500  70.2167      5.73        86
#
#    Cloudiness  Wind Speed Country        Date
# 0          35        4.99      GS  1690102512
# 1           1        4.88      BR  1690102981
# 2          38        2.17      CL  1690102521
# 3          97        7.16      BB  1690102981
# 4          99       16.40      TF  1690102518

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = city_data_df["Humidity"]*100,
    scale = 0.1,
    color = "City",
    alpha = .5
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,_size)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# A max temperature lower than 27 degrees but higher than 21
# Wind speed less than 4.5 m/s
# Zero cloudiness
ideal_df = city_data_df.loc[(city_data_df["Max Temp"]<= 28) 
                            &(city_data_df["Max Temp"]>= 20)
                            &(city_data_df["Wind Speed"]< 5)
                            &(city_data_df["Cloudiness"]< 10)]

# Drop any rows with null values
ideal_df = ideal_df.dropna()

# Display sample data
ideal_df.head()
# Out:
#     City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 1         1                  coruripe -10.1256  -36.1756     22.46        79
# 10       10                   landeck  47.1301   10.5636     22.35        50
# 30       30                 majdanpek  44.4277   21.9460     24.28        52
# 40       40               punta gorda  26.9298  -82.0454     27.78        87
# 43       43  petropavlovsk-kamchatsky  53.0452  158.6483     21.33        68
#
#     Cloudiness  Wind Speed Country        Date
# 1            1        4.88      BR  1690102981
# 10           7        0.71      AT  1690102982
# 30           6        4.03      RS  1690102984
# 40           8        3.13      US  1690102985
# 43           0        4.00      RU  1690102517

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_df[['City', 'Country','Lat','Lng','Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df.head()
# Out:
#                         City Country      Lat       Lng  Humidity Hotel Name
# 1                   coruripe      BR -10.1256  -36.1756        79
# 10                   landeck      AT  47.1301   10.5636        50
# 30                 majdanpek      RS  44.4277   21.9460        52
# 40               punta gorda      US  26.9298  -82.0454        87
# 43  petropavlovsk-kamchatsky      RU  53.0452  158.6483        68

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
categories ="accommodation.hotel"
limit=1

# Set the search parameters
params = { 
    "categories":categories,
    "limit":limit,
    "apiKey":geoapify_key,
}



# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():

    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{row['Lng']},{row['Lat']},{radius}"
    params["bias"] = f"proximity:{row['Lng']},{row['Lat']}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params).json()

    # Convert the API response to JSON format
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# coruripe - nearest hotel: No hotel found
# landeck - nearest hotel: Hotel Sonne
# majdanpek - nearest hotel: No hotel found
# punta gorda - nearest hotel: SpringHill Suites by Marriott Punta Gorda Harborside
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# remire-montjoly - nearest hotel: Complexe Belova
# spanish springs - nearest hotel: No hotel found
# kill devil hills - nearest hotel: Mariner Days Inn & Suites
# airway heights - nearest hotel: Days Inn and Suites Airway Heights
# morondava - nearest hotel: Hotel Sharon Menabe
# mahalapye - nearest hotel: Lme Lodge
# morehead city - nearest hotel: Bask Hotel Big Rock Landing, Trademark Collection by Wyndham
# persembe - nearest hotel: Hotel Dedeevi
# tsiombe - nearest hotel: No hotel found
# chililabombwe - nearest hotel: Kumapili Hotel
# zouerate - nearest hotel: فندق تيرس زمور
# belaya kholunitsa - nearest hotel: Спортивная
# nchelenge - nearest hotel: No hotel found
# maun - nearest hotel: Center Lodge Conference Center
# gillette - nearest hotel: Montgomery Hotel
#                          City Country      Lat       Lng  Humidity  \
# 1                    coruripe      BR -10.1256  -36.1756        79
# 10                    landeck      AT  47.1301   10.5636        50
# 30                  majdanpek      RS  44.4277   21.9460        52
# 40                punta gorda      US  26.9298  -82.0454        87
# 43   petropavlovsk-kamchatsky      RU  53.0452  158.6483        68
# 141           remire-montjoly      GF   4.9167  -52.2667        94
# 156           spanish springs      US  39.6491 -119.7074        32
# 166          kill devil hills      US  36.0307  -75.6760        87
# 174            airway heights      US  47.6446 -117.5933        41
# 175                 morondava      MG -20.2833   44.2833        67
# 232                 mahalapye      BW -23.1041   26.8142        35
# 262             morehead city      US  34.7229  -76.7260        89
# 396                  persembe      TR  41.0656   37.7714        56
# 410                   tsiombe      MG -25.3000   45.4833        43
# 424             chililabombwe      ZM -12.3648   27.8229        35
# 436                  zouerate      MR  22.7187  -12.4521        40
# 458         belaya kholunitsa      RU  58.8400   50.8528        43
# 491                 nchelenge      ZM  -9.3451   28.7340        37
# 492                      maun      BW -19.9833   23.4167        27
# 504                  gillette      US  44.2911 -105.5022        45
#
#                                             Hotel Name
# 1                                       No hotel found
# 10                                         Hotel Sonne
# 30                                      No hotel found
# 40   SpringHill Suites by Marriott Punta Gorda Harb...
# 43                                  ООО Постоялый двор
# 141                                    Complexe Belova
# 156                                     No hotel found
# 166                          Mariner Days Inn & Suites
# 174                 Days Inn and Suites Airway Heights
# 175                                Hotel Sharon Menabe
# 232                                          Lme Lodge
# 262  Bask Hotel Big Rock Landing, Trademark Collect...
# 396                                      Hotel Dedeevi
# 410                                     No hotel found
# 424                                     Kumapili Hotel
# 436                                     فندق تيرس زمور
# 458                                         Спортивная
# 491                                     No hotel found
# 492                     Center Lodge Conference Center
# 504                                   Montgomery Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = (city_data_df["Humidity"])*100,
    scale = 0.1,
    color = "City",
    alpha = .5,
    hover_cols = ['City', 'Humidity','Hotel Name', 'Country']
)

# Display the map
# ***************************************************************************************
# *The sample image for this portion showed more than was specified in the instructions *
# *I followed the image instead of the written instructions since it included more      *
# ***************************************************************************************
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,_size,Humidity,Hotel Name,Country)
